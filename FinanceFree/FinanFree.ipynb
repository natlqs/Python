# %% [markdown]
# ## Episode 1 & 2

# %%
import pandas as pd
import numpy as np
# import yfinance as yf
import tushare as ts
import datetime as dt
from pandas_datareader import data as pdr
# yf.pdr_override()

stock = input("Enter a stock ticker symbol: ")
# print(stock)
startyear = 2011
startmonth = 7
startday = 1

start= dt.datetime(startyear, startmonth, startday)
now = dt.datetime.now()

df = ts.get_hist_data(stock, start = str(start), end = str(now))
print(df)
ma = 50
smaString = 'sma' + str(ma)

df[smaString] = df.iloc[:,3].rolling(window=ma).mean()
df = df.iloc[ma:]
emasUsed = [3, 5, 8, 10, 12, 15, 30, 35, 40, 45, 50, 60]
for x in emasUsed:
    ema = x
    df['ema_' + str(x)] = round(df.iloc[:, 3].ewm(span=ema, adjust=False).mean(), 2)
# print(df.tail())
pos = 0
num = 0
percentchange = []

for i in df.index:
    cmin = min(df['ema_3'][i], df['ema_5'][i],  df['ema_8'][i], df['ema_10'][i], df['ema_12'][i], df['ema_15'][i],)
    cmax = max(df['ema_30'][i], df['ema_35'][i],  df['ema_40'][i], df['ema_45'][i], df['ema_50'][i], df['ema_60'][i],)
    close = df['close'][i]
    if(cmin > cmax):
        print('red white blue')
        if (pos ==0):
            bp = close          # bp: buy price
            pos = 1
            print('buying now at ' + str(bp))
        
    elif(cmin < cmax):
        print('blue white blue')
        if (pos == 1):
            pos = 0
            sp = close          # sp: sell price 
            print('selling now at ' + str(sp))
            pc = (sp/bp-1)*100         # profit 
            percentchange.append(pc)

    if (num == df['close'].count() -1 and pos ==1):
        pos = 0
        sp = close
        print('selling now at ' + str(sp))
        pc = (sp/bp-1) * 100
        percentchange.append(pc)
    num +=1
print(percentchange)

gains = 0
ng = 0      # number of gains
losses = 0
nl = 0      # number of losses
totalr = 1  # total of returns / revenue

for i in percentchange:
    if(i>0):
        gains += i
        ng += 1
    else:
        losses +=i
        nl +=1
    totalr = totalr*((i/100) +1)

totalr = round((totalr-1)*100, 2)


if (ng>0):
    avggain = gains/ng
    maxr = str(max(percentchange))
else:
    avggain = 0
    maxr = 'undifined'

if (nl>0):
    avgloss = losses/nl
    maxl = str(min(percentchange))
    ratio = str(-avggain/avgloss)       # gain/loss ratio
else:
    avgloss = 0
    maxl = 'undifined'
    ratio = 'inf'

if(ng>0 or nl > 0):
    battingavg = ng/(ng+nl)     # win rate
else:
    battingavg=0

print()
print("Results for "+ stock +" going back to "+str(df.index[0])+", Sample size: "+str(ng+nl)+" trades")
print("EMAs used: "+str(emasUsed))
print("Batting Avg: "+ str(battingavg))
print("Gain/loss ratio: "+ ratio)
print("Average Gain: "+ str(avggain))
print("Average Loss: "+ str(avgloss))
print("Max Return: "+ maxr)
print("Max Loss: "+ maxl)
print("Total return over "+str(ng+nl)+ " trades: "+ str(totalr)+"%" )
#print("Example return Simulating "+str(n)+ " trades: "+ str(nReturn)+"%" )
print()
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#                open     high    close      low    volume  price_change  \
# date
# 2022-05-27  1759.99  1780.00  1755.16  1753.01  25119.58         12.36
# 2022-05-26  1761.00  1761.00  1742.80  1730.00  28053.44        -12.71
# 2022-05-25  1765.27  1772.00  1755.51  1747.00  22388.69         -4.49
# 2022-05-24  1786.00  1787.00  1760.00  1755.50  27342.22        -21.00
# 2022-05-23  1800.00  1803.89  1781.00  1772.00  22157.13        -19.01
# ...             ...      ...      ...      ...       ...           ...
# 2019-12-03  1133.00  1133.00  1118.00  1117.74  27340.93        -15.00
# 2019-12-02  1118.20  1140.02  1133.00  1118.20  30784.41          4.00
# 2019-11-29  1165.50  1165.50  1129.00  1112.89  82397.32        -46.80
# 2019-11-28  1194.97  1197.51  1175.80  1169.02  28844.99        -14.15
# 2019-11-27  1192.80  1196.62  1189.95  1184.51  19848.81          4.95
#
#             p_change       ma5      ma10      ma20     v_ma5    v_ma10  \
# date
# 2022-05-27      0.71  1758.894  1763.748  1777.644  25012.21  25954.74
# 2022-05-26     -0.72  1767.864  1766.056  1776.510  28378.22  25515.84
# 2022-05-25     -0.26  1770.504  1768.043  1774.770  26722.78  24914.31
# 2022-05-24     -1.18  1771.602  1769.292  1775.645  27215.13  25706.71
# 2022-05-23     -1.06  1773.202  1769.911  1776.644  25775.63  26984.41
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-03     -1.32  1149.150  1149.150  1149.150  37843.29  37843.29
# 2019-12-02      0.35  1156.938  1156.938  1156.938  40468.88  40468.88
# 2019-11-29     -3.98  1164.917  1164.917  1164.917  43697.04  43697.04
# 2019-11-28     -1.19  1182.875  1182.875  1182.875  24346.90  24346.90
# 2019-11-27      0.42  1189.950  1189.950  1189.950  19848.81  19848.81
#
#               v_ma20  turnover
# date
# 2022-05-27  30082.74      0.20
# 2022-05-26  31054.96      0.22
# 2022-05-25  32335.18      0.18
# 2022-05-24  32610.74      0.22
# 2022-05-23  32691.26      0.18
# ...              ...       ...
# 2019-12-03  37843.29      0.22
# 2019-12-02  40468.88      0.25
# 2019-11-29  43697.04      0.66
# 2019-11-28  24346.90      0.23
# 2019-11-27  19848.81      0.16
#
# [605 rows x 14 columns]
# red white blue
# buying now at 1794.43
# red white blue
# red white blue
# blue white blue
# selling now at 1707.0
# red white blue
# buying now at 1780.5
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# blue white blue
# selling now at 2043.0
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# red white blue
# buying now at 1900.0
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# blue white blue
# selling now at 2071.29
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# red white blue
# buying now at 2126.03
# red white blue
# red white blue
# blue white blue
# selling now at 2009.0
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# red white blue
# buying now at 2158.0
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# blue white blue
# selling now at 2145.0
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# blue white blue
# red white blue
# buying now at 1148.0
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# red white blue
# blue white blue
# selling now at 1122.33
# blue white blue
# blue white blue
# blue white blue
# red white blue
# buying now at 1175.8
# red white blue
# selling now at 1189.95
# [-4.872299281666049, 14.743049705139, 9.015263157894736, -5.5046259930480845, -0.6024096385542133, -2.2360627177700376, 1.203435958496346]
#
# Results for 600519 going back to 2022-03-11, Sample size: 7 trades
# EMAs used: [3, 5, 8, 10, 12, 15, 30, 35, 40, 45, 50, 60]
# Batting Avg: 0.42857142857142855
# Gain/loss ratio: 2.51845102896272
# Average Gain: 8.320582940510027
# Average Loss: -3.303849407759596
# Max Return: 14.743049705139
# Max Loss: -5.5046259930480845
# Total return over 7 trades: 10.58%

# %% [markdown]
# ## Episode 3

# %%
import pandas as pd
import numpy as np
# import yfinance as yf
import tushare as ts
import datetime as dt
from pandas_datareader import data as pdr
# yf.pdr_override()

stock = input("Enter a stock ticker symbol: ")
# print(stock)
startyear = 2011
startmonth = 7
startday = 1

start= dt.datetime(startyear, startmonth, startday)
now = dt.datetime.now()

df = ts.get_hist_data(stock, start = str(start), end = str(now))
print(df)
ma = 50
smaString = 'sma' + str(ma)

df[smaString] = df.iloc[:,3].rolling(window=ma).mean()
df = df.iloc[ma:]
emasUsed = [3, 5, 8, 10, 12, 15, 30, 35, 40, 45, 50, 60]
for x in emasUsed:
    ema = x
    df['ema_' + str(x)] = round(df.iloc[:, 3].ewm(span=ema, adjust=False).mean(), 2)
# print(df.tail())
pos = 0
num = 0
percentchange = []

for i in df.index:
    cmin = min(df['ema_3'][i], df['ema_5'][i],  df['ema_8'][i], df['ema_10'][i], df['ema_12'][i], df['ema_15'][i],)
    cmax = max(df['ema_30'][i], df['ema_35'][i],  df['ema_40'][i], df['ema_45'][i], df['ema_50'][i], df['ema_60'][i],)
    close = df['close'][i]
    if(cmin > cmax):
        print('red white blue')
        if (pos ==0):
            bp = close          # bp: buy price
            pos = 1
            print('buying now at ' + str(bp))
        
    elif(cmin < cmax):
        print('blue white blue')
        if (pos == 1):
            pos = 0
            sp = close          # sp: sell price 
            print('selling now at ' + str(sp))
            pc = (sp/bp-1)*100         # profit 
            percentchange.append(pc)

    if (num == df['close'].count() -1 and pos ==1):
        pos = 0
        sp = close
        print('selling now at ' + str(sp))
        pc = (sp/bp-1) * 100
        percentchange.append(pc)
    num +=1
print(percentchange)

gains = 0
ng = 0      # number of gains
losses = 0
nl = 0      # number of losses
totalr = 1  # total of returns / revenue

for i in percentchange:
    if(i>0):
        gains += i
        ng += 1
    else:
        losses +=i
        nl +=1
    totalr = totalr*((i/100) +1)

totalr = round((totalr-1)*100, 2)


if (ng>0):
    avggain = gains/ng
    maxr = str(max(percentchange))
else:
    avggain = 0
    maxr = 'undifined'

if (nl>0):
    avgloss = losses/nl
    maxl = str(min(percentchange))
    ratio = str(-avggain/avgloss)       # gain/loss ratio
else:
    avgloss = 0
    maxl = 'undifined'
    ratio = 'inf'

if(ng>0 or nl > 0):
    battingavg = ng/(ng+nl)     # win rate
else:
    battingavg=0

print()
print("Results for "+ stock +" going back to "+str(df.index[0])+", Sample size: "+str(ng+nl)+" trades")
print("EMAs used: "+str(emasUsed))
print("Batting Avg: "+ str(battingavg))
print("Gain/loss ratio: "+ ratio)
print("Average Gain: "+ str(avggain))
print("Average Loss: "+ str(avgloss))
print("Max Return: "+ maxr)
print("Max Loss: "+ maxl)
print("Total return over "+str(ng+nl)+ " trades: "+ str(totalr)+"%" )
#print("Example return Simulating "+str(n)+ " trades: "+ str(nReturn)+"%" )
print()
